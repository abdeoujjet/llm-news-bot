# %%
# importar librerias
import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from urllib.parse import urljoin
from openai import OpenAI
import pandas as pd
from readability import Document

# %% [markdown]
# ### Estructura
# - Scraping de todos los links de la web (guardamos link, titulo de cada una y un id)
# - Utilizamos un LLM (gemma 3) para filtrar las noticias mas relevantes (formato Json)
# - Las noticias más importantes resumirlas en 30-40 caracteres
# - Enviar el titulo, la noticia resumida y el link a un bot de telegram

# %% [markdown]
# ## Scraping de la web

# %%
# url de noticias de mallorca
url = "https://www.ultimahora.es/sucesos.html"
id = 0
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

try:
    response = requests.get(url, headers=headers, timeout=10)
    response.raise_for_status()

    soup = BeautifulSoup(response.content, 'html.parser')
    news_list = []

    # Encontrar todos los contenedores de noticias
    news_containers = soup.find_all('div', class_='news-item')

    for container in news_containers:
        # Extraer titulo
        title_element = container.find(['h2', 'h3'], class_='news-heading')
        if not title_element:
            continue

        link_element = title_element.find('a', href=True)
        if not link_element:
            continue

        title = title_element.get_text(strip=True)
        link = urljoin(url, link_element['href'])

        news_list.append({
            'title': title,
            'url': link,
            'id' : id
        })
        id = id + 1

    # Mostrar resultados
    print(f"Noticias encontradas: {len(news_list)}")
    for idx, news in enumerate(news_list, 1):
        print(f"\nNoticia {idx}:")
        print(f"Título: {news['title']}")
        print(f"Enlace: {news['url']}")
        print(f"id: {news['id']}")

except requests.exceptions.RequestException as e:
    print(f"Error de conexión: {e}")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Noticias encontradas: 32
#
# Noticia 1:
# Título: Agreden y roban a un hombre que sufrió una indisposición en el coche tras sacar 500 euros en el banco
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396345/sucesos-mallorca-joven-carne-ayuda-aparcar-hombre-sintio-indispuesto-son-gotleu-roba-500-euros-tras-agredirle.html
# id: 0
#
# Noticia 2:
# Título: Condenado un guardia civil por acoso telefónico a un examigo en Marratxí
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396861/sucesos-mallorca-condenado-guardia-civil-por-acoso-telefonico-examigo-marratxi.html
# id: 1
#
# Noticia 3:
# Título: Denuncian robos en el cementerio de Llucmajor: «No respetan a los muertos»
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2393421/denuncian-robos-cementerio-llucmajor-respetan-muertos.html
# id: 2
#
# Noticia 4:
# Título: Muere la ciclista que fue arrollada por una furgoneta en Santa Margalida
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396523/sucesos-mallorca-muere-ciclista-fue-arrollada-por-furgoneta-santa-margalida.html
# id: 3
#
# Noticia 5:
# Título: El rapero Kanye West paga parte de su deuda en Mallorca: la factura pendiente de un restaurante de Palma
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396425/rapero-kanye-west-paga-parte-deuda-mallorca-factura-pendiente-restaurante-palma.html
# id: 4
#
# Noticia 6:
# Título: Medio centenar de detenidos en Palma tras el adelanto de la 'Operación Verano'
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396605/medio-centenar-detenidos-palma-tras-adelanto-operacion-verano.html
# id: 5
#
# Noticia 7:
# Título: Un herido tras colisionar dos vehículos que realizaron maniobras prohibidas
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396559/herido-tras-colisionar-dos-vehiculos-realizaron-maniobras-prohibidas.html
# id: 6
#
# Noticia 8:
# Título: Arrestada en Sa Pobla tras robar 900 euros y un reloj del cajón del propietario de la casa en la que limpiaba
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395983/arrestada-pobla-tras-robar-900-euros-reloj-del-cajon-del-propietario-casa-limpiaba.html
# id: 7
#
# Noticia 9:
# Título: Una discusión entre dos hombres en un bus de la EMT acaba con uno de ellos ensangrentado
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2396007/discusion-entre-dos-hombres-bus-emt-acaba-uno-ellos-ensangrentado.html
# id: 8
#
# Noticia 10:
# Título: Detenido el autor del robo de un reloj de 245.000 euros a un joven en el centro de Palma
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395903/detenido-autor-del-robo-reloj-245000-joven-centro-palma.html
# id: 9
#
# Noticia 11:
# Título: Condenado un profesor de instituto de Palma por acoso sexual a alumnas de entre 13 y 16 años
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395797/condenado-profesor-instituto-palma-por-acoso-sexual-alumnas-entre-anos.html
# id: 10
#
# Noticia 12:
# Título: Un hombre agrede a otro con un palo en la cabeza mientras esperaban a que sus hijos salieran del colegio
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395833/hombre-agrede-palo-cabeza-otro-salida-del-colegio-palma.html
# id: 11
#
# Noticia 13:
# Título: Un hombre, en estado crítico tras ser apuñalado por su novia
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397299/hombre-estado-critico-tras-ser-apunalado-por-novia.html
# id: 12
#
# Noticia 14:
# Título: Cae la Mafia del Cobre que firmaba como tal: 102 robos por valor de 2,5 millones en 8 autonomías
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397165/cae-mafia-del-cobre-firmaba-como-tal-102-robos-por-valor-millones-autonomias.html
# id: 13
#
# Noticia 15:
# Título: Desalojo en Ibiza por explosiones en un céntrico aparcamiento
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397149/explosiones-centrico-aparcamiento-ibiza-1.html
# id: 14
#
# Noticia 16:
# Título: Un herido grave en una colisión entre dos vehículos en Ibiza
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397141/herido-grave-colision-entre-dos-vehiculos-ibiza.html
# id: 15
#
# Noticia 17:
# Título: Alarma al declararse un incendio «incontrolado» en Sant Jordi
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396833/alarma-declararse-incendio-incontrolado-san-jordi.html
# id: 16
#
# Noticia 18:
# Título: El niño que se cayó de un tercer piso en Ibiza es trasladado a Son Espases tras ser intervenido
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396369/nino-cayo-tercer-piso-ibiza-trasladado-son-espases-tras-ser-intervenido.html
# id: 17
#
# Noticia 19:
# Título: Simonet comparecerá en el Parlament para abordar la denuncia a la granja de Llucmajor
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396365/simonet-comparecera-parlament-para-abordar-denuncia-granja-llucmajor.html
# id: 18
#
# Noticia 20:
# Título: Grave un niño de 9 años tras caer desde un tercer piso en Ibiza
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2396285/grave-nino-anos-tras-caer-desde-tercer-piso-ibiza.html
# id: 19
#
# Noticia 21:
# Título: Nuevo escándalo de Kanye West: La Policía investiga un impago de casi medio millón de euros del rapero en Mallorca
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2396191/nuevo-escandalo-kanye-west-policia-investiga-impago-casi-medio-millon-euros-del-rapero-mallorca.html
# id: 20
#
# Noticia 22:
# Título: El 'time-lapse' que documenta a las gallinas de Llucmajor sin salir al exterior durante seis días
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395875/time-lapse-documenta-gallinas-llucmajor-salir-exterior-durante-seis-dias.html
# id: 21
#
# Noticia 23:
# Título: La Guardia Civil y Agricultura inspeccionan la granja de gallinas de Llucmajor, aunque el Govern descarta por ahora su cierre
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395779/govern-descarta-por-ahora-cierre-cautelar-granja-gallinas.html
# id: 22
#
# Noticia 24:
# Título: El PSIB reclama el cierre inmediato de la granja avícola denunciada en Llucmajor
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395813/psib-reclama-cierre-inmediato-granja-avicola-denunciada-llucmajor.html
# id: 23
#
# Noticia 25:
# Título: Presunto caso de violencia machista en un pueblo de Cáceres
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395733/presunto-caso-violencia-machista-pueblo-caceres.html
# id: 24
#
# Noticia 26:
# Título: Greenpeace exige el cierre inmediato de la macrogranja avícola de Llucmajor
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395703/greenpeace-exige-cierre-inmediato-macrogranja-avicola-llucmajor.html
# id: 25
#
# Noticia 27:
# Título: Una pelea en un hostal de Favara acaba con un fallecido y tres heridos, uno de ellos grave
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395573/pelea-hostal-favara-acaba-fallecido-tres-heridos-uno-ellos-grave.html
# id: 26
#
# Noticia 28:
# Título: Asaltan de madrugada el piso de un policía nacional de Manacor y le roban joyas y relojes
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2394941/asaltan-madrugada-piso-policia-nacional-manacor-roban-joyas-relojes.html
# id: 27
#
# Noticia 29:
# Título: Atropello masivo en Liverpool durante la celebración de la Premier
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395481/hombre-arrestado-tras-chocar-varios-peatones-centro-liverpool.html
# id: 28
#
# Noticia 30:
# Título: La Policía Nacional adelanta el refuerzo de efectivos en Balears de cara al verano
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395235/policia-nacional-adelanta-refuerzo-efectivos-balears-cara-verano.html
# id: 29
#
# Noticia 31:
# Título: Agrede a un joven por la espalda, le hace un 'mataleón' y se da a la fuga en Cala Millor
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395197/agrede-joven-por-espalda-hace-mataleon-fuga-cala-millor.html
# id: 30
#
# Noticia 32:
# Título: Detenido el patrón de una patera que trajo a Mallorca a 23 migrantes
# Enlace: https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395179/detenido-patron-patera-trajo-mallorca-migrantes.html
# id: 31

# %% [markdown]
# ## Filtro gemma3

# %%
from openai import OpenAI

modelo_filtro_titulos = OpenAI( base_url="http://localhost:11434/v1" , api_key= "ollama")

# %%
# Crear lista simplificada con solo title e id para ahorrar tiempo y tokens
datos_simplificados = [
    {"title": item["title"], "id": item["id"]}
    for item in news_list
]

# %%
msg = [
    {
        "role": "system",
        "content": """Eres un editor experto en análisis de noticias. Tu tarea es:
        
                    1. Analizar esta lista de titulares de noticias
                    2. Seleccionar los 10 más relevantes según estos criterios:
                    - Impacto social
                    - Gravedad del suceso
                    - Relevancia pública
                    - Novedad del acontecimiento

                    REQUISITOS DE RESPUESTA:
                    - Devuelve ÚNICAMENTE un array JSON válido, sin comentario adicionales ni nada mas.
                    - Usa EXACTAMENTE los mismos títulos recibidos
                    - Devuelve exactamente el mismo id relacionado al título de la noticia
                    - Estructura exacta requerida:
                    "noticias_relevantes": [
                            {
                        "titulo": "Texto exacto del titular original",
                        "categoria": "asesinato|violencia|robo|accidente|corrupción|otros",
                        "id": id exacto de la noticia,
                        "impacto_emocional": 0-10,
                        "prioridad": "alta|media|baja"
                        },
                    ]
                    """
    },
    {
        "role": "user",
        "content": f"LISTA DE TITULARES:\n{datos_simplificados}"
    }
  ]

# %%
# Comento par que no se ejecute sin quereer otra vez.
response = modelo_filtro_titulos.chat.completions.create(
    model="gemma3:4b",
    messages=msg,
    response_format={"type": "json_object"}  # forzar al modelo a que devulva un json

)

print(json.loads(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 2
#       1 # Comento par que no se ejecute sin quereer otra vez.
# ----> 2 response = modelo_filtro_titulos.chat.completions.create(
#       3     model="gemma3:4b",
#       4     messages=msg,
#       5     response_format={"type": "json_object"}  # forzar al modelo a que devulva un json
#       6
#       7 )
#       9 print(json.loads(response.choices[0].message.content))
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\openai\_utils\_utils.py:287, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285             msg = f"Missing required argument: {quote(missing[0])}"
#     286     raise TypeError(msg)
# --> 287 return func(*args, **kwargs)
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\openai\resources\chat\completions\completions.py:925, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     882 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     883 def create(
#     884     self,
#    (...)
#     922     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     923 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     924     validate_response_format(response_format)
# --> 925     return self._post(
#     926         "/chat/completions",
#     927         body=maybe_transform(
#     928             {
#     929                 "messages": messages,
#     930                 "model": model,
#     931                 "audio": audio,
#     932                 "frequency_penalty": frequency_penalty,
#     933                 "function_call": function_call,
#     934                 "functions": functions,
#     935                 "logit_bias": logit_bias,
#     936                 "logprobs": logprobs,
#     937                 "max_completion_tokens": max_completion_tokens,
#     938                 "max_tokens": max_tokens,
#     939                 "metadata": metadata,
#     940                 "modalities": modalities,
#     941                 "n": n,
#     942                 "parallel_tool_calls": parallel_tool_calls,
#     943                 "prediction": prediction,
#     944                 "presence_penalty": presence_penalty,
#     945                 "reasoning_effort": reasoning_effort,
#     946                 "response_format": response_format,
#     947                 "seed": seed,
#     948                 "service_tier": service_tier,
#     949                 "stop": stop,
#     950                 "store": store,
#     951                 "stream": stream,
#     952                 "stream_options": stream_options,
#     953                 "temperature": temperature,
#     954                 "tool_choice": tool_choice,
#     955                 "tools": tools,
#     956                 "top_logprobs": top_logprobs,
#     957                 "top_p": top_p,
#     958                 "user": user,
#     959                 "web_search_options": web_search_options,
#     960             },
#     961             completion_create_params.CompletionCreateParamsStreaming
#     962             if stream
#     963             else completion_create_params.CompletionCreateParamsNonStreaming,
#     964         ),
#     965         options=make_request_options(
#     966             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     967         ),
#     968         cast_to=ChatCompletion,
#     969         stream=stream or False,
#     970         stream_cls=Stream[ChatCompletionChunk],
#     971     )
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\openai\_base_client.py:1239, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1225 def post(
#    1226     self,
#    1227     path: str,
#    (...)
#    1234     stream_cls: type[_StreamT] | None = None,
#    1235 ) -> ResponseT | _StreamT:
#    1236     opts = FinalRequestOptions.construct(
#    1237         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1238     )
# -> 1239     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\openai\_base_client.py:969, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     967 response = None
#     968 try:
# --> 969     response = self._client.send(
#     970         request,
#     971         stream=stream or self._should_stream_response_body(request=request),
#     972         **kwargs,
#     973     )
#     974 except httpx.TimeoutException as err:
#     975     log.debug("Encountered httpx.TimeoutException", exc_info=True)
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     910 self._set_timeout(request)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#     921     if not stream:
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     939 request = next(auth_flow)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#     948         try:
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     976 for hook in self._event_hooks["request"]:
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#     981     for hook in self._event_hooks["response"]:
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1009     raise RuntimeError(
#    1010         "Attempted to send an async request with a sync Client instance."
#    1011     )
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#    1018 response.request = request
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#     254 return Response(
#     255     status_code=resp.status,
#     256     headers=resp.headers,
#     257     stream=ResponseStream(resp.stream),
#     258     extensions=resp.extensions,
#     259 )
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_sync\http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\aoujjet\OneDrive - Grupo Sampol\Escritorio\llm-news-bot\env\lib\site-packages\httpcore\_backends\sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
# # guardo repsuesta para no ejecutarlo mas veces.
# respuesta_modelo = {"noticias_relevantes": [
#     {"title": "Nuevo escándalo de Kanye West: La Policía investiga un impago de casi medio millón de euros del rapero en Mallorca", "categoria": "otros", "id": 0, "impacto_emocional": 7, "prioridad": "alta"},
#     {"title": "Condenado en Palma el octogenario que entró sin permiso en casa de sus inquilinas para oler sus bragas", "categoria": "violencia", "id": 2, "impacto_emocional": 9, "prioridad": "alta"},
#     {"title": "Una colisión en la Ma-13 provoca varios kilómetros de retenciones a la altura de Santa Maria", "categoria": "accidente", "id": 11, "impacto_emocional": 4, "prioridad": "media"},
#     {"title": "Piden 28 años cárcel a un hombre por abusos sexuales y vejaciones a tres menores de edad en Palma", "categoria": "otros", "id": 12, "impacto_emocional": 10, "prioridad": "alta"},
#     {"title": "Avícola Son Perot abre sus puertas para mostrar la realidad de la granja ante «las imágenes manipuladas»", "categoria": "otros", "id": 18, "impacto_emocional": 8, "prioridad": "alta"},
#     {"title": "Una empleada del hogar roba 6.400 euros y cubertería de plata a la octogenaria a la que cuidaba en Palma", "categoria": "violencia", "id": 33, "impacto_emocional": 7, "prioridad": "alta"},
#     {"title": "Un incendio en una casa de Palma destapa una plantación de marihuana", "categoria": "otros", "id": 32, "impacto_emocional": 6, "prioridad": "media"},
#     {"title": "Presunto caso de violencia machista en un pueblo de Cáceres", "categoria": "violencia", "id": 22, "impacto_emocional": 9, "prioridad": "alta"},
#     {"title": "Una pelea en un hostal de Favara acaba con un fallecido y tres heridos, uno de ellos grave", "categoria": "violencia", "id": 23, "impacto_emocional": 10, "prioridad": "alta"},
#     {"title": "Aparecen pintadas e intentan pegar fuego a los Juzgados de Ibiza", "categoria": "otros", "id": 34, "impacto_emocional": 5, "prioridad": "media"}
# ]}

respuesta_modelo = json.loads(response.choices[0].message.content)

# %%
link_por_id = {noticia['id']: noticia['url'] for noticia in news_list}


# Paso 2: añadir el link a cada entrada en respuesta_modelo
for entrada in respuesta_modelo['noticias_relevantes']:
    noticia_id = entrada['id']
    if noticia_id in link_por_id:
        entrada['url'] = link_por_id[noticia_id]
    else:
        entrada['url'] = None  # o lo que prefieras si no encuentra el link

# %% [markdown]
# ## Resumir urls seleccionadas

# %%
def obtener_noticia(url):
    """
    Dada una URL, realiza scraping del contenido principal de la noticia
    y devuelve el texto limpio para ser resumido posteriormente.
    """
    if url:
        try:
            headers = {
                "User-Agent": "Mozilla/5.0"
            }
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()

            # Extraer HTML limpio con Readability
            doc = Document(response.text)
            html_limpio = doc.summary()

            # Parsear con BeautifulSoup para limpiar etiquetas
            soup = BeautifulSoup(html_limpio, 'html.parser')
            texto = soup.get_text(separator='\n')

            # Limpiar espacios en blanco
            texto = '\n'.join([line.strip() for line in texto.splitlines() if line.strip()])

            return texto

        except Exception as e:
            print("[ERROR] ", e)
            return ""
    else:
        return None


def resumir_web(url , modelo):
    texto = obtener_noticia(url)
    if texto:
        # Creamos el mensaje para el modelo
        msg = [
        {
            "role": "system",
            "content": """Eres un editor experto en análisis de noticias. Tu tarea es resumir la 
                        noticia al maximo, de unos aproximadamente 70 caracteres, captando la 
                        atencion del lector. No debes inventar nada, ni ser sensacionalista,
                        pero si debes intentar captar la atencion del lector con el resumen
                        maximo posible.
                        """
        },
        {
            "role": "user",
            "content": f"LISTA DE TITULARES:\n{texto}"
        }
        ]

        # Enviamos el mensaje al modelo junto al texto para resumirlo
        response = modelo.chat.completions.create(
        model="gemma3:4b",
        messages=msg
        )
        # print(response.choices[0].message.content)

        return response.choices[0].message.content
    else:
        return None

# %%
modelo_resumen_noticia = OpenAI( base_url="http://localhost:11434/v1" , api_key= "ollama")

for noticias in respuesta_modelo['noticias_relevantes']:
    noticias['resumen_breve'] = resumir_web(noticias['url'] , modelo_resumen_noticia)
    print(noticias['titulo'])
    print(noticias['resumen_breve'])
    print(noticias['url'])
    print("- - - - - - - - - - - - - - - - - - - - - - - - - - - ")
# Out:
# Agreden y roban a un hombre que sufrió una indisposición en el coche tras sacar 500 euros en el banco
# Robo y violencia en Palma: Detenido por robar 500€ tras ayudar a víctima. ¡Alarma en Son Gotleu!
# https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396345/sucesos-mallorca-joven-carne-ayuda-aparcar-hombre-sintio-indispuesto-son-gotleu-roba-500-euros-tras-agredirle.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Muere la ciclista que fue arrollada por una furgoneta en Santa Margalida
# Ciclista italiana de 49 años fallece tras accidente en Mallorca. Grave lesión tras atropello.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396523/sucesos-mallorca-muere-ciclista-fue-arrollada-por-furgoneta-santa-margalida.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Un hombre, en estado crítico tras ser apuñalado por su novia
# **Resumen:**
#
# Mujer apuñala a su novio en Latina; víctima en estado crítico. Investigación en curso.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397299/hombre-estado-critico-tras-ser-apunalado-por-novia.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Cae la Mafia del Cobre que firmaba como tal: 102 robos por valor de 2,5 millones en 8 autonomías
# **Operación Kuroma:** Desarticulada red criminal que robaba toneladas de cobre, afectando servicios esenciales y con ramificaciones en España y Rumanía.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397165/cae-mafia-del-cobre-firmaba-como-tal-102-robos-por-valor-millones-autonomias.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Una pelea en un hostal de Favara acaba con un fallecido y tres heridos, uno de ellos grave
# Favara: Pelea en hostal deja un muerto y tres heridos. Investigación en curso.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395573/pelea-hostal-favara-acaba-fallecido-tres-heridos-uno-ellos-grave.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Condenado un guardia civil por acoso telefónico a un examigo en Marratxí
# Guardia civil condenado a multa por acoso telefónico.
# Lesiones psíquicas confirmadas.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396861/sucesos-mallorca-condenado-guardia-civil-por-acoso-telefonico-examigo-marratxi.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Detenido el patrón de una patera que trajo a Mallorca a 23 migrantes
# Detenido en Palma: hombre de Gambia investigado por trata de migrantes.
#
# https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395179/detenido-patron-patera-trajo-mallorca-migrantes.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Presunto caso de violencia machista en un pueblo de Cáceres
# Aldeanueva del Camino: Mujer fallece tras heridas de arma blanca.
# Investigación en curso por posible violencia de género.
#
# https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395733/presunto-caso-violencia-machista-pueblo-caceres.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Arrestada en Sa Pobla tras robar 900 euros y un reloj del cajón del propietario de la casa en la que limpiaba
# Detenida una empleada de limpieza en Sa Pobla por un robo de 1.500€ y un Rolex.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395983/arrestada-pobla-tras-robar-900-euros-reloj-del-cajon-del-propietario-casa-limpiaba.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Asaltan de madrugada el piso de un policía nacional de Manacor y le roban joyas y relojes
# Manacor: Asalto y robo frustrado. Ladrón arrestado tras devolver objetos robados y admitir el error.
# https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2394941/asaltan-madrugada-piso-policia-nacional-manacor-roban-joyas-relojes.html
# - - - - - - - - - - - - - - - - - - - - - - - - - - -

# %%
respuesta_modelo['noticias_relevantes']
# Out:
# [{'titulo': 'Agreden y roban a un hombre que sufrió una indisposición en el coche tras sacar 500 euros en el banco',
#   'categoria': 'violencia|robo',
#   'id': 0,
#   'impacto_emocional': 8,
#   'prioridad': 'alta',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396345/sucesos-mallorca-joven-carne-ayuda-aparcar-hombre-sintio-indispuesto-son-gotleu-roba-500-euros-tras-agredirle.html',
#   'resumen_breve': 'Robo y violencia en Palma: Detenido por robar 500€ tras ayudar a víctima. ¡Alarma en Son Gotleu!'},
#  {'titulo': 'Muere la ciclista que fue arrollada por una furgoneta en Santa Margalida',
#   'categoria': 'accidente|muerte',
#   'id': 3,
#   'impacto_emocional': 9,
#   'prioridad': 'alta',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/28/2396523/sucesos-mallorca-muere-ciclista-fue-arrollada-por-furgoneta-santa-margalida.html',
#   'resumen_breve': 'Ciclista italiana de 49 años fallece tras accidente en Mallorca. Grave lesión tras atropello.'},
#  {'titulo': 'Un hombre, en estado crítico tras ser apuñalado por su novia',
#   'categoria': 'violencia|asesinato',
#   'id': 12,
#   'impacto_emocional': 10,
#   'prioridad': 'alta',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397299/hombre-estado-critico-tras-ser-apunalado-por-novia.html',
#   'resumen_breve': '**Resumen:**\n\nMujer apuñala a su novio en Latina; víctima en estado crítico. Investigación en curso.'},
#  {'titulo': 'Cae la Mafia del Cobre que firmaba como tal: 102 robos por valor de 2,5 millones en 8 autonomías',
#   'categoria': 'corrupción|robo',
#   'id': 13,
#   'impacto_emocional': 7,
#   'prioridad': 'alta',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2397165/cae-mafia-del-cobre-firmaba-como-tal-102-robos-por-valor-millones-autonomias.html',
#   'resumen_breve': '**Operación Kuroma:** Desarticulada red criminal que robaba toneladas de cobre, afectando servicios esenciales y con ramificaciones en España y Rumanía.'},
#  {'titulo': 'Una pelea en un hostal de Favara acaba con un fallecido y tres heridos, uno de ellos grave',
#   'categoria': 'violencia|asesinato',
#   'id': 26,
#   'impacto_emocional': 9,
#   'prioridad': 'alta',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395573/pelea-hostal-favara-acaba-fallecido-tres-heridos-uno-ellos-grave.html',
#   'resumen_breve': 'Favara: Pelea en hostal deja un muerto y tres heridos. Investigación en curso.'},
#  {'titulo': 'Condenado un guardia civil por acoso telefónico a un examigo en Marratxí',
#   'categoria': 'corrupción|violencia',
#   'id': 1,
#   'impacto_emocional': 6,
#   'prioridad': 'media',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/29/2396861/sucesos-mallorca-condenado-guardia-civil-por-acoso-telefonico-examigo-marratxi.html',
#   'resumen_breve': 'Guardia civil condenado a multa por acoso telefónico.\nLesiones psíquicas confirmadas.'},
#  {'titulo': 'Detenido el patrón de una patera que trajo a Mallorca a 23 migrantes',
#   'categoria': 'delincuencia|migración',
#   'id': 31,
#   'impacto_emocional': 5,
#   'prioridad': 'media',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/26/2395179/detenido-patron-patera-trajo-mallorca-migrantes.html',
#   'resumen_breve': 'Detenido en Palma: hombre de Gambia investigado por trata de migrantes.\n'},
#  {'titulo': 'Presunto caso de violencia machista en un pueblo de Cáceres',
#   'categoria': 'violencia|asesinato',
#   'id': 24,
#   'impacto_emocional': 8,
#   'prioridad': 'media',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395733/presunto-caso-violencia-machista-pueblo-caceres.html',
#   'resumen_breve': 'Aldeanueva del Camino: Mujer fallece tras heridas de arma blanca.\nInvestigación en curso por posible violencia de género.\n'},
#  {'titulo': 'Arrestada en Sa Pobla tras robar 900 euros y un reloj del cajón del propietario de la casa en la que limpiaba',
#   'categoria': 'robo',
#   'id': 7,
#   'impacto_emocional': 6,
#   'prioridad': 'media',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2395983/arrestada-pobla-tras-robar-900-euros-reloj-del-cajon-del-propietario-casa-limpiaba.html',
#   'resumen_breve': 'Detenida una empleada de limpieza en Sa Pobla por un robo de 1.500€ y un Rolex.'},
#  {'titulo': 'Asaltan de madrugada el piso de un policía nacional de Manacor y le roban joyas y relojes',
#   'categoria': 'robo|violencia',
#   'id': 27,
#   'impacto_emocional': 7,
#   'prioridad': 'media',
#   'url': 'https://www.ultimahora.es/sucesos/ultimas/2025/05/27/2394941/asaltan-madrugada-piso-policia-nacional-manacor-roban-joyas-relojes.html',
#   'resumen_breve': 'Manacor: Asalto y robo frustrado. Ladrón arrestado tras devolver objetos robados y admitir el error.'}]

# %% [markdown]
# ## Difusion

# %%
def enviar_telegram(mensaje, bot_token, chat_ids):
    """
    Envía un mensaje a múltiples chat_ids a través de un bot de Telegram.
    
    Parámetros:
        mensaje (str): El contenido del mensaje a enviar.
        bot_token (str): El token del bot de Telegram.
        chat_ids (list): Lista de chat_id (puede ser grupo o usuario).
    """
    for chat_id in chat_ids:
        url = f"https://api.telegram.org/bot{bot_token}/sendMessage"
        payload = {
            "chat_id": chat_id,
            "text": mensaje,
            "parse_mode": "HTML"  # Puedes usar "Markdown" si prefieres
        }
        try:
            response = requests.post(url, data=payload)
            if not response.ok:
                print(f"Error al enviar a {chat_id}: {response.text}")
        except Exception as e:
            print(f"Excepción al enviar a {chat_id}: {str(e)}")

# %%
# from config_usuario import config_telegram

usuario_actual = "abde"  # Puedes pedirlo como parámetro o argumento de función
chat_ids = config_telegram["usuarios"].get(usuario_actual, [])
bot_token = config_telegram["bot_token"]

# Construye el mensaje con tus noticias
for noticia in noticias:
    mensaje = f"<b>{noticia['titulo']}</b>\n{noticia['resumen_breve']}\n{noticia['url']}"
    enviar_telegram(mensaje, bot_token, chat_ids)
